# %%
import pandas as pd
exam = pd.read_csv("exam.csv")
exam
# Out:
#     id  nclass  front  back  design
# 0    1       1     50    98      50
# 1    2       1     60    97      60
# 2    3       1     45    86      78
# 3    4       1     30    98      58
# 4    5       2     25    80      65
# 5    6       2     50    89      98
# 6    7       2     80    90      45
# 7    8       2     90    78      25
# 8    9       3     20    98      15
# 9   10       3     50    98      45
# 10  11       3     65    65      65
# 11  12       3     45    85      32
# 12  13       4     46    98      65
# 13  14       4     48    87      12
# 14  15       4     75    56      78
# 15  16       4     58    98      65
# 16  17       5     65    68      98
# 17  18       5     80    78      90
# 18  19       5     89    68      87
# 19  20       5     78    83      58

# %%
exam.query('nclass ==1')
# Out:
#    id  nclass  front  back  design
# 0   1       1     50    98      50
# 1   2       1     60    97      60
# 2   3       1     45    86      78
# 3   4       1     30    98      58

# %%
exam.query('nclass != 1')
# Out:
#     id  nclass  front  back  design
# 4    5       2     25    80      65
# 5    6       2     50    89      98
# 6    7       2     80    90      45
# 7    8       2     90    78      25
# 8    9       3     20    98      15
# 9   10       3     50    98      45
# 10  11       3     65    65      65
# 11  12       3     45    85      32
# 12  13       4     46    98      65
# 13  14       4     48    87      12
# 14  15       4     75    56      78
# 15  16       4     58    98      65
# 16  17       5     65    68      98
# 17  18       5     80    78      90
# 18  19       5     89    68      87
# 19  20       5     78    83      58

# %%
exam.query('front > 50')
# Out:
#     id  nclass  front  back  design
# 1    2       1     60    97      60
# 6    7       2     80    90      45
# 7    8       2     90    78      25
# 10  11       3     65    65      65
# 14  15       4     75    56      78
# 15  16       4     58    98      65
# 16  17       5     65    68      98
# 17  18       5     80    78      90
# 18  19       5     89    68      87
# 19  20       5     78    83      58

# %%
exam.query('front < 50')
# Out:
#     id  nclass  front  back  design
# 2    3       1     45    86      78
# 3    4       1     30    98      58
# 4    5       2     25    80      65
# 8    9       3     20    98      15
# 11  12       3     45    85      32
# 12  13       4     46    98      65
# 13  14       4     48    87      12

# %%
exam.query('back >= 50')
# Out:
#     id  nclass  front  back  design
# 0    1       1     50    98      50
# 1    2       1     60    97      60
# 2    3       1     45    86      78
# 3    4       1     30    98      58
# 4    5       2     25    80      65
# 5    6       2     50    89      98
# 6    7       2     80    90      45
# 7    8       2     90    78      25
# 8    9       3     20    98      15
# 9   10       3     50    98      45
# 10  11       3     65    65      65
# 11  12       3     45    85      32
# 12  13       4     46    98      65
# 13  14       4     48    87      12
# 14  15       4     75    56      78
# 15  16       4     58    98      65
# 16  17       5     65    68      98
# 17  18       5     80    78      90
# 18  19       5     89    68      87
# 19  20       5     78    83      58

# %%
exam.query('back <= 80')
# Out:
#     id  nclass  front  back  design
# 4    5       2     25    80      65
# 7    8       2     90    78      25
# 10  11       3     65    65      65
# 14  15       4     75    56      78
# 16  17       5     65    68      98
# 17  18       5     80    78      90
# 18  19       5     89    68      87

# %%
exam.query('nclass == 1 & front>=50')
# Out:
#    id  nclass  front  back  design
# 0   1       1     50    98      50
# 1   2       1     60    97      60

# %%
exam.query('front>=90 | back>=90')
# Out:
#     id  nclass  front  back  design
# 0    1       1     50    98      50
# 1    2       1     60    97      60
# 3    4       1     30    98      58
# 6    7       2     80    90      45
# 7    8       2     90    78      25
# 8    9       3     20    98      15
# 9   10       3     50    98      45
# 12  13       4     46    98      65
# 15  16       4     58    98      65

# %%
exam.query('nclass==1 | nclass==3 | nclass==5')
# Out:
#     id  nclass  front  back  design
# 0    1       1     50    98      50
# 1    2       1     60    97      60
# 2    3       1     45    86      78
# 3    4       1     30    98      58
# 8    9       3     20    98      15
# 9   10       3     50    98      45
# 10  11       3     65    65      65
# 11  12       3     45    85      32
# 16  17       5     65    68      98
# 17  18       5     80    78      90
# 18  19       5     89    68      87
# 19  20       5     78    83      58

# %%
exam.query('nclass in [1, 3, 5]')
# Out:
#     id  nclass  front  back  design
# 0    1       1     50    98      50
# 1    2       1     60    97      60
# 2    3       1     45    86      78
# 3    4       1     30    98      58
# 8    9       3     20    98      15
# 9   10       3     50    98      45
# 10  11       3     65    65      65
# 11  12       3     45    85      32
# 16  17       5     65    68      98
# 17  18       5     80    78      90
# 18  19       5     89    68      87
# 19  20       5     78    83      58

# %%
nclass1 = exam.query('nclass==1')
nclass2 = exam.query('nclass ==2')

# %%
nclass1['front'].mean()
# Out:
# np.float64(46.25)

# %%
nclass2['front'].mean()
# Out:
# np.float64(61.25)

# %%
exam['front']
# Out:
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78
# Name: front, dtype: int64

# %%
exam['nclass']
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     2
# 5     2
# 6     2
# 7     2
# 8     3
# 9     3
# 10    3
# 11    3
# 12    4
# 13    4
# 14    4
# 15    4
# 16    5
# 17    5
# 18    5
# 19    5
# Name: nclass, dtype: int64

# %%
exam[['nclass', 'front', 'back']]
# Out:
#     nclass  front  back
# 0        1     50    98
# 1        1     60    97
# 2        1     45    86
# 3        1     30    98
# 4        2     25    80
# 5        2     50    89
# 6        2     80    90
# 7        2     90    78
# 8        3     20    98
# 9        3     50    98
# 10       3     65    65
# 11       3     45    85
# 12       4     46    98
# 13       4     48    87
# 14       4     75    56
# 15       4     58    98
# 16       5     65    68
# 17       5     80    78
# 18       5     89    68
# 19       5     78    83

# %%
exam.drop(columns='front')
# Out:
#     id  nclass  back  design
# 0    1       1    98      50
# 1    2       1    97      60
# 2    3       1    86      78
# 3    4       1    98      58
# 4    5       2    80      65
# 5    6       2    89      98
# 6    7       2    90      45
# 7    8       2    78      25
# 8    9       3    98      15
# 9   10       3    98      45
# 10  11       3    65      65
# 11  12       3    85      32
# 12  13       4    98      65
# 13  14       4    87      12
# 14  15       4    56      78
# 15  16       4    98      65
# 16  17       5    68      98
# 17  18       5    78      90
# 18  19       5    68      87
# 19  20       5    83      58

# %%
exam.drop(columns=['front', 'back'])
# Out:
#     id  nclass  design
# 0    1       1      50
# 1    2       1      60
# 2    3       1      78
# 3    4       1      58
# 4    5       2      65
# 5    6       2      98
# 6    7       2      45
# 7    8       2      25
# 8    9       3      15
# 9   10       3      45
# 10  11       3      65
# 11  12       3      32
# 12  13       4      65
# 13  14       4      12
# 14  15       4      78
# 15  16       4      65
# 16  17       5      98
# 17  18       5      90
# 18  19       5      87
# 19  20       5      58

# %%
exam.query('nclass==1')['front']
# Out:
# 0    50
# 1    60
# 2    45
# 3    30
# Name: front, dtype: int64

# %%
exam.query('front>=50')[['id', 'front']].head(10)
# Out:
#     id  front
# 0    1     50
# 1    2     60
# 5    6     50
# 6    7     80
# 7    8     90
# 9   10     50
# 10  11     65
# 14  15     75
# 15  16     58
# 16  17     65

# %%
exam.query('front>=50') \
    [['id', 'front']] \
    .head(10)
# Out:
#     id  front
# 0    1     50
# 1    2     60
# 5    6     50
# 6    7     80
# 7    8     90
# 9   10     50
# 10  11     65
# 14  15     75
# 15  16     58
# 16  17     65

# %%
exam.sort_values('front')
# Out:
#     id  nclass  front  back  design
# 8    9       3     20    98      15
# 4    5       2     25    80      65
# 3    4       1     30    98      58
# 2    3       1     45    86      78
# 11  12       3     45    85      32
# 12  13       4     46    98      65
# 13  14       4     48    87      12
# 0    1       1     50    98      50
# 9   10       3     50    98      45
# 5    6       2     50    89      98
# 15  16       4     58    98      65
# 1    2       1     60    97      60
# 10  11       3     65    65      65
# 16  17       5     65    68      98
# 14  15       4     75    56      78
# 19  20       5     78    83      58
# 17  18       5     80    78      90
# 6    7       2     80    90      45
# 18  19       5     89    68      87
# 7    8       2     90    78      25

# %%
exam.sort_values('front', ascending=False)
# Out:
#     id  nclass  front  back  design
# 7    8       2     90    78      25
# 18  19       5     89    68      87
# 6    7       2     80    90      45
# 17  18       5     80    78      90
# 19  20       5     78    83      58
# 14  15       4     75    56      78
# 10  11       3     65    65      65
# 16  17       5     65    68      98
# 1    2       1     60    97      60
# 15  16       4     58    98      65
# 0    1       1     50    98      50
# 5    6       2     50    89      98
# 9   10       3     50    98      45
# 13  14       4     48    87      12
# 12  13       4     46    98      65
# 2    3       1     45    86      78
# 11  12       3     45    85      32
# 3    4       1     30    98      58
# 4    5       2     25    80      65
# 8    9       3     20    98      15

# %%
exam.sort_values(['nclass', 'front'])
# Out:
#     id  nclass  front  back  design
# 3    4       1     30    98      58
# 2    3       1     45    86      78
# 0    1       1     50    98      50
# 1    2       1     60    97      60
# 4    5       2     25    80      65
# 5    6       2     50    89      98
# 6    7       2     80    90      45
# 7    8       2     90    78      25
# 8    9       3     20    98      15
# 11  12       3     45    85      32
# 9   10       3     50    98      45
# 10  11       3     65    65      65
# 12  13       4     46    98      65
# 13  14       4     48    87      12
# 15  16       4     58    98      65
# 14  15       4     75    56      78
# 16  17       5     65    68      98
# 19  20       5     78    83      58
# 17  18       5     80    78      90
# 18  19       5     89    68      87

# %%
exam.sort_values(['nclass', 'front'], ascending=[True, False])
# Out:
#     id  nclass  front  back  design
# 1    2       1     60    97      60
# 0    1       1     50    98      50
# 2    3       1     45    86      78
# 3    4       1     30    98      58
# 7    8       2     90    78      25
# 6    7       2     80    90      45
# 5    6       2     50    89      98
# 4    5       2     25    80      65
# 10  11       3     65    65      65
# 9   10       3     50    98      45
# 11  12       3     45    85      32
# 8    9       3     20    98      15
# 14  15       4     75    56      78
# 15  16       4     58    98      65
# 13  14       4     48    87      12
# 12  13       4     46    98      65
# 18  19       5     89    68      87
# 17  18       5     80    78      90
# 19  20       5     78    83      58
# 16  17       5     65    68      98
